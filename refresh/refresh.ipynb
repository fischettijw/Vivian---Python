# %%
print("Hello World")
# Out:
# Hello World

# %%
print(45)
# Out:
# 45

# %%
name1 = "Vivian"
print(name1)
# Out:
# Vivian

# %%
name2 = "John"
print(name2)
# Out:
# John

# %%
print(5<2)
# Out:
# False

# %%
x = range(1,100)
print(x[4])
# Out:
# 5
